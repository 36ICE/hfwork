# %%
import akshare as ak

# %%
stock_board_concept_hist_min_em_df = ak.stock_board_concept_hist_min_em(symbol="长寿药", period="1")
print(stock_board_concept_hist_min_em_df)
# Out:
#                  日期时间       开盘       收盘       最高       最低    成交量         成交额  \
# 0    2023-12-15 09:30  1040.09  1040.09  1040.09  1038.46   7514  10215986.0
# 1    2023-12-15 09:31  1040.09  1038.54  1042.37  1038.54  45930  54897072.0
# 2    2023-12-15 09:32  1038.99  1037.90  1040.48  1037.88  37915  39554098.0
# 3    2023-12-15 09:33  1037.89  1036.73  1039.20  1036.43  41373  55677992.0
# 4    2023-12-15 09:34  1037.02  1038.26  1038.35  1037.02  29878  42163016.0
# ..                ...      ...      ...      ...      ...    ...         ...
# 236  2023-12-15 14:56  1030.33  1030.24  1030.61  1029.90  14410  18509672.0
# 237  2023-12-15 14:57  1030.14  1030.25  1030.54  1029.82  15158  19151563.0
# 238  2023-12-15 14:58  1030.22  1030.14  1030.22  1030.14    456    760719.0
# 239  2023-12-15 14:59  1030.14  1030.14  1030.14  1030.14      0         0.0
# 240  2023-12-15 15:00  1030.14  1030.52  1030.52  1030.14  27635  34534949.0
#
#           最新价
# 0    1040.085
# 1    1040.804
# 2    1040.173
# 3    1039.378
# 4    1039.103
# ..        ...
# 236  1032.785
# 237  1032.766
# 238  1032.765
# 239  1032.765
# 240  1032.736
#
# [241 rows x 8 columns]

# %%
stock_board_concept_graph_ths_df = ak.stock_board_concept_graph_ths(symbol="通用航空")
print(stock_board_concept_graph_ths_df)
# Out:
#      产业链    名称   涨跌幅     现价
# 0   设备制造  新大洲A  1.01   3.00
# 1   设备制造  中航高科  0.36  22.10
# 2   设备制造  航新科技  0.07  13.39
# 3   设备制造  通裕重工  0.00   2.40
# 4   设备制造   德奥退  0.00   0.53
# 5   设备制造  四创电子  0.72  20.70
# 6   设备制造  中直股份  1.08  38.58
# 7   设备制造  威海广泰  1.30   9.12
# 8   设备制造  川大智胜  1.40  15.46
# 9   航空运营  华夏幸福  0.00   1.84
# 10  航空运营  海特高新  0.21   9.50
# 11  航空运营  中信海直  0.60   8.23
# 12  航空运营  洪都航空  0.99  21.09
# 13    其他  中化岩土  0.00   2.90
# 14    其他  应流股份  1.10  14.34

# %%
stock_board_concept_name_ths_df = ak.stock_board_concept_name_ths()
print(stock_board_concept_name_ths_df)
# Out:
#              日期    概念名称 成分股数量                                             网址  \
# 0    2023-12-07   多模态AI    59  http://q.10jqka.com.cn/gn/detail/code/309104/
# 1    2023-11-27  长安汽车概念   188  http://q.10jqka.com.cn/gn/detail/code/309094/
# 2    2023-11-14    短剧游戏    40  http://q.10jqka.com.cn/gn/detail/code/309093/
# 3    2023-11-14    智能座舱    61  http://q.10jqka.com.cn/gn/detail/code/309092/
# 4    2023-11-14    华为昇腾    28  http://q.10jqka.com.cn/gn/detail/code/309090/
# ..          ...     ...   ...                                            ...
# 526        None      金改  None  http://q.10jqka.com.cn/gn/detail/code/300265/
# 527        None  京津冀一体化  None  http://q.10jqka.com.cn/gn/detail/code/300061/
# 580        None    苹果概念  None  http://q.10jqka.com.cn/gn/detail/code/300309/
# 581        None   PM2.5  None  http://q.10jqka.com.cn/gn/detail/code/300134/
# 615        None     石墨烯  None  http://q.10jqka.com.cn/gn/detail/code/300337/
#
#          代码
# 0    309104
# 1    309094
# 2    309093
# 3    309092
# 4    309090
# ..      ...
# 526  300265
# 527  300061
# 580  300309
# 581  300134
# 615  300337
#
# [396 rows x 5 columns]

# %%
stock_board_concept_cons_ths_df = ak.stock_board_concept_cons_ths(symbol="人脸识别")
print(stock_board_concept_cons_ths_df)
# Out:
#     序号      代码    名称     现价    涨跌幅    涨跌    涨速     换手     量比     振幅     成交额  \
# 0    1  603660  苏州科达  11.75  10.02  1.07  0.00  18.04  13.18   1.50  10.47亿
# 1    2  300044  赛为智能   7.06   7.13  0.47  0.00  27.59   2.33  13.66  13.31亿
# 2    3  002177  御银股份   4.42   9.95  0.40  0.00  10.51   3.41   9.70   3.45亿
# 3    4  002777  久远银海  27.66   1.32  0.36  0.00   5.73   1.29   7.55   6.44亿
# 4    5  300588  熙菱信息  14.19   1.79  0.25  0.00  19.09   1.59   5.81   3.98亿
# ..  ..     ...   ...    ...    ...   ...   ...    ...    ...    ...     ...
# 74  75  688322  奥比中光  35.36  -3.78 -1.39  0.80   3.65   1.11   6.07   2.87亿
# 75  76  002362  汉王科技  27.50  -7.19 -2.13 -0.15  32.23   1.68   7.56  18.54亿
# 76  77  603189  网达软件  19.58  -9.98 -2.17  0.00  14.54   0.62   4.97   7.86亿
# 77  78  688787  海天瑞声  77.85  -3.91 -3.17  0.12   6.36   0.69   5.07   2.08亿
# 78  79  688039  当虹科技  38.00  -8.83 -3.68  0.21  11.30   0.73   8.40   4.92亿
#
#       流通股     流通市值     市盈率
# 0   4.94亿   58.07亿      --
# 1   6.85亿   48.35亿  233.56
# 2   7.61亿   33.64亿  203.27
# 3   3.99亿  110.48亿   74.15
# 4   1.44亿   20.50亿      --
# ..    ...      ...     ...
# 74  2.19亿   77.40亿      --
# 75  2.07亿   56.93亿      --
# 76  2.70亿   52.78亿      --
# 77  0.41亿   32.11亿      --
# 78  1.12亿   42.53亿      --
#
# [79 rows x 14 columns]

# %%
stock_board_concept_hist_ths_df = ak.stock_board_concept_hist_ths(start_year='2020', symbol="一带一路")
print(stock_board_concept_hist_ths_df)
# Out:
#              日期       开盘价       最高价       最低价       收盘价          成交量  \
# 0    2020-01-02  1154.249  1165.727  1152.970  1165.089   6151305100
# 1    2020-01-03  1167.015  1174.117  1164.478  1172.325   5041909100
# 2    2020-01-06  1170.345  1186.953  1167.274  1178.527   6790413500
# 3    2020-01-07  1178.083  1190.517  1178.083  1190.517   5416339900
# 4    2020-01-08  1189.191  1189.824  1172.995  1176.491   6084009300
# ..          ...       ...       ...       ...       ...          ...
# 954  2023-12-08  1665.000  1669.557  1645.683  1645.683  10675720900
# 955  2023-12-11  1638.578  1661.251  1628.013  1660.719  10787745800
# 956  2023-12-12  1660.119  1670.979  1656.958  1670.979   8219360600
# 957  2023-12-13  1669.066  1675.231  1660.995  1660.995   7949752100
# 958  2023-12-14  1665.385  1665.385  1665.385  1665.385     61970755
#
#               成交额
# 0    4.467495e+10
# 1    3.583539e+10
# 2    4.793528e+10
# 3    3.789916e+10
# 4    4.270683e+10
# ..            ...
# 954  8.236269e+10
# 955  8.072250e+10
# 956  6.591420e+10
# 957  6.425369e+10
# 958  4.941835e+08
#
# [959 rows x 7 columns]

# %%
stock_board_cons_ths_df = ak.stock_board_cons_ths(symbol="885611")
print(stock_board_cons_ths_df)
# Out:
#       序号      代码    名称     现价   涨跌幅    涨跌    涨速     换手    量比     振幅     成交额  \
# 0      1  300792  壹网壹创  26.15  4.06  1.02 -0.08   5.96  1.93   7.64   3.28亿
# 1      2  300805  电声股份   9.65  1.47  0.14  0.10   4.82  1.83   5.89   1.36亿
# 2      3  000785  居然之家   3.47  1.46  0.05  0.00   0.25  0.90   2.34   0.52亿
# 3      4  002264   新华都   5.75  1.23  0.07  0.00   1.15  1.35   1.94   0.43亿
# 4      5  000702  正虹科技   6.21  1.14  0.07  0.16   2.08  0.65   2.61   0.34亿
# ..   ...     ...   ...    ...   ...   ...   ...    ...   ...    ...     ...
# 137  138  688322  奥比中光  35.36 -3.78 -1.39  0.80   3.65  1.11   6.07   2.87亿
# 138  139  002313  日海智能  12.59 -4.33 -0.57  0.08  24.84  1.60  13.91  12.48亿
# 139  140  300366  创意信息  13.39 -6.69 -0.96  0.00   8.95  1.78   8.08   6.18亿
# 140  141  300781  因赛集团  41.52 -7.94 -3.58 -0.07  30.45  0.90  13.50  10.67亿
# 141  142  603189  网达软件  19.58 -9.98 -2.17  0.00  14.54  0.62   4.97   7.86亿
#
#         流通股     流通市值     市盈率
# 0     2.09亿   54.58亿   41.16
# 1     2.87亿   27.71亿   98.81
# 2    59.65亿  206.99亿   14.22
# 3     6.54亿   37.59亿   19.50
# 4     2.67亿   16.56亿      --
# ..      ...      ...     ...
# 137   2.19亿   77.40亿      --
# 138   3.74亿   47.12亿      --
# 139   5.02亿   67.24亿      --
# 140   0.81亿   33.67亿  104.34
# 141   2.70亿   52.78亿      --
#
# [142 rows x 14 columns]

# %%
stock_board_concept_cons_ths_df = ak.stock_board_concept_cons_ths(symbol="人脸识别")
print(stock_board_concept_cons_ths_df)
# Out:
#     序号      代码    名称     现价    涨跌幅    涨跌    涨速     换手     量比     振幅     成交额  \
# 0    1  603660  苏州科达  11.75  10.02  1.07  0.00  18.04  13.18   1.50  10.47亿
# 1    2  300044  赛为智能   7.06   7.13  0.47  0.00  27.59   2.33  13.66  13.31亿
# 2    3  002177  御银股份   4.42   9.95  0.40  0.00  10.51   3.41   9.70   3.45亿
# 3    4  002777  久远银海  27.66   1.32  0.36  0.00   5.73   1.29   7.55   6.44亿
# 4    5  300588  熙菱信息  14.19   1.79  0.25  0.00  19.09   1.59   5.81   3.98亿
# ..  ..     ...   ...    ...    ...   ...   ...    ...    ...    ...     ...
# 74  75  688322  奥比中光  35.36  -3.78 -1.39  0.80   3.65   1.11   6.07   2.87亿
# 75  76  002362  汉王科技  27.50  -7.19 -2.13 -0.15  32.23   1.68   7.56  18.54亿
# 76  77  603189  网达软件  19.58  -9.98 -2.17  0.00  14.54   0.62   4.97   7.86亿
# 77  78  688787  海天瑞声  77.85  -3.91 -3.17  0.12   6.36   0.69   5.07   2.08亿
# 78  79  688039  当虹科技  38.00  -8.83 -3.68  0.21  11.30   0.73   8.40   4.92亿
#
#       流通股     流通市值     市盈率
# 0   4.94亿   58.07亿      --
# 1   6.85亿   48.35亿  233.56
# 2   7.61亿   33.64亿  203.27
# 3   3.99亿  110.48亿   74.15
# 4   1.44亿   20.50亿      --
# ..    ...      ...     ...
# 74  2.19亿   77.40亿      --
# 75  2.07亿   56.93亿      --
# 76  2.70亿   52.78亿      --
# 77  0.41亿   32.11亿      --
# 78  1.12亿   42.53亿      --
#
# [79 rows x 14 columns]

# %%
stock_market_activity_legu_df = ak.stock_market_activity_legu()
print(stock_market_activity_legu_df)
# Out:
#         item                         value
# 0         上涨                        1907.0
# 1         涨停                          44.0
# 2       真实涨停                          37.0
# 3   st st*涨停                           5.0
# 4         下跌                        2936.0
# 5         跌停                          20.0
# 6       真实跌停                          11.0
# 7   st st*跌停                          10.0
# 8         平盘                         243.0
# 9         停牌                           1.0
# 10       活跃度  37.49%\n\t\t\t\t\t\t\t\t\t\t
# 11      统计日期           2023-12-14 15:00:00
# C:\apps\Anaconda3\envs\hfwork\lib\site-packages\akshare\stock_feature\stock_market_legu.py:22: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   temp_df = pd.read_html(r.text)[0]

# %%
stock_board_change_em_df = ak.stock_board_change_em()
print(stock_board_change_em_df)
# Out:
#         板块名称   涨跌幅         主力净流入  板块异动总次数 板块异动最频繁个股及所属类型-股票代码  \
# 0       融资融券 -0.17 -1.814881e+06     4923              301459
# 1       国企改革  0.30 -4.456255e+05     2543              603153
# 2       机构重仓 -0.24 -7.061196e+05     2516              603153
# 3       预盈预增 -0.08 -5.425108e+05     1610              603153
# 4       广东板块 -0.21 -4.365005e+05     1428              002031
# ..       ...   ...           ...      ...                 ...
# 548     航空机场 -0.67 -1.232751e+04        2              600009
# 549      人造肉 -0.31 -5.098935e+03        1              603182
# 550  MLOps概念 -1.46 -1.717381e+04        1              688031
# 551   第四代半导体  0.73  3.454206e+02        1              601179
# 552     MLCC -0.40 -2.102305e+03        1              002585
#
#     板块异动最频繁个股及所属类型-股票名称 板块异动最频繁个股及所属类型-买卖方向  \
# 0                   C丰茂                大笔买入
# 1                  上海建科                大笔卖出
# 2                  上海建科                大笔卖出
# 3                  上海建科                大笔卖出
# 4                  巨轮智能                大笔买入
# ..                  ...                 ...
# 548                上海机场                大笔卖出
# 549                嘉华股份                大笔卖出
# 550              星环科技-U                大笔卖出
# 551                中国西电                大笔卖出
# 552                双星新材                大笔买入
#
#                                        板块具体异动类型列表及出现次数
# 0    [{'t': 8201, 'ct': 913}, {'t': 8203, 'ct': 704...
# 1    [{'t': 8193, 'ct': 430}, {'t': 8194, 'ct': 333...
# 2    [{'t': 8193, 'ct': 556}, {'t': 8194, 'ct': 474...
# 3    [{'t': 8193, 'ct': 293}, {'t': 8194, 'ct': 265...
# 4    [{'t': 8193, 'ct': 221}, {'t': 8201, 'ct': 219...
# ..                                                 ...
# 548       [{'t': 8214, 'ct': 1}, {'t': 8216, 'ct': 1}]
# 549                             [{'t': 8218, 'ct': 1}]
# 550                             [{'t': 8202, 'ct': 1}]
# 551                             [{'t': 8215, 'ct': 1}]
# 552                             [{'t': 8214, 'ct': 1}]
#
# [553 rows x 8 columns]

# %%
stock_board_concept_name_em_df = ak.stock_board_concept_name_em()
print(stock_board_concept_name_em_df)
# Out:
#       排名      板块名称    板块代码       最新价      涨跌额   涨跌幅           总市值    换手率  \
# 0      1  昨日连板_含一字  BK1051  39637.21  1102.52  2.86   72128534000  19.10
# 1      2  昨日涨停_含一字  BK1050    666.06    15.38  2.36  241065667000  16.02
# 2      3      昨日涨停  BK0815  66498.24  1465.59  2.25  203971134000  18.43
# 3      4      股权转让  BK0803    625.08    11.58  1.89   93856909000   1.48
# 4      5      进口博览  BK0850    921.88    15.30  1.69  262398511000   0.87
# ..   ...       ...     ...       ...      ...   ...           ...    ...
# 433  434      昨日触板  BK0817      0.54    -0.01 -1.82  255136930000   8.26
# 434  435      华为昇腾  BK0995   1166.72   -21.65 -1.82  252279649000   3.71
# 435  436     3D摄像头  BK0901   1163.28   -23.96 -2.02  465866928000   3.05
# 436  437      华为欧拉  BK1013   1156.62   -23.93 -2.03  207454137000   4.51
# 437  438     多模态AI  BK1153   1030.18   -22.51 -2.14  558923424000   4.98
#
#      上涨家数  下跌家数  领涨股票  领涨股票-涨跌幅
# 0       8     6  南宁百货      9.95
# 1      19    18  南宁百货      9.95
# 2      18    18   克劳斯     10.04
# 3      14     6  廊坊发展      9.93
# 4      13     3  龙头股份      9.97
# ..    ...   ...   ...       ...
# 433     6    22  广西能源      5.67
# 434     1    20  三联虹普      0.81
# 435     4     7  联创电子      0.68
# 436     1    12  普元信息      0.18
# 437     2    25  苏州科达     10.02
#
# [438 rows x 12 columns]

# %%
nlp_ownthink_df = ak.nlp_ownthink(word="人工智能", indicator="tag")
print(nlp_ownthink_df)
# Out:
# ['中国通信学会', '学科']

# %%
#中国国家金融与发展实验室-中国宏观杠杆率数据
macro_cnbs_df = ak.macro_cnbs()
print(macro_cnbs_df)
# Out:
#           年份  居民部门  非金融企业部门  政府部门  中央政府  地方政府  实体经济部门  金融部门资产方  金融部门负债方
# 0    1992-12   7.5     90.0   8.3   4.4   3.9   105.8      7.8      7.2
# 1    1993-03   7.5     91.1   8.1   4.2   3.9   106.7      7.8      7.3
# 2    1993-06   7.4     91.1   8.2   4.4   3.8   106.7      7.7      7.3
# 3    1993-09   7.3     90.2   8.3   4.6   3.7   105.8      7.7      7.3
# 4    1993-12   7.0     87.8   7.8   4.2   3.6   102.6      8.9      7.1
# ..       ...   ...      ...   ...   ...   ...     ...      ...      ...
# 117  2022-03  61.8    158.2  47.3  19.9  27.4   267.3     49.2     62.6
# 118  2022-06  62.0    160.3  49.6  20.2  29.4   271.9     50.0     63.9
# 119  2022-09  62.1    160.9  49.8  20.9  28.9   272.7     49.3     63.9
# 120  2022-12  61.9    160.9  50.4  21.4  29.0   273.1     50.0     64.4
# 121  2023-03  63.3    167.0  51.5  21.4  30.1   281.8     52.7     65.6
#
# [122 rows x 9 columns]

# %%
#东方财富-经济数据一览-中国-企业商品价格指数, 数据区间从 20050101-至今
macro_china_qyspjg_df = ak.macro_china_qyspjg()
print(macro_china_qyspjg_df)
# Out:
#             月份  总指数-指数值  总指数-同比增长  总指数-环比增长  农产品-指数值   农产品-同比增长  农产品-环比增长  \
# 0    2023年10月份    97.90 -2.197802 -0.709939    93.00 -16.890080 -1.691332
# 1    2023年09月份    98.60 -3.048181  0.612245    94.60 -15.535714 -1.252610
# 2    2023年08月份    98.00 -4.203324  1.030928    95.80 -10.966543 -0.519211
# 3    2023年07月份    97.00 -5.916586  1.570681    96.30  -9.577465 -3.410231
# 4    2023年06月份    95.50 -9.220532 -0.417101    99.70  -3.391473 -0.100200
# ..         ...      ...       ...       ...      ...        ...       ...
# 221  2005年05月份   103.16 -5.738304  0.340434   100.88 -14.761301 -0.561853
# 222  2005年04月份   102.81 -5.903350 -0.647468   101.45 -13.290598 -2.150849
# 223  2005年03月份   103.48 -4.485878 -1.278382   103.68  -9.386471 -3.928836
# 224  2005年02月份   104.82 -2.046538  0.143308   107.92  -2.871029  1.600452
# 225  2005年01月份   104.67 -1.957662 -0.626602   106.22  -3.864603 -0.018825
#
#      矿产品-指数值   矿产品-同比增长  矿产品-环比增长  煤油电-指数值   煤油电-同比增长  煤油电-环比增长
# 0     107.60   9.683996  0.279590    97.70  -9.537037 -1.013171
# 1     107.30  12.004175  0.000000    98.70 -11.717352  2.812500
# 2     107.30  15.625000  2.581262    96.00 -16.083916  4.575163
# 3     104.60  12.231760  4.704705    91.80 -21.336761  2.000000
# 4      99.90   1.834862  0.705645    90.00 -25.373134 -3.846154
# ..       ...        ...       ...      ...        ...       ...
# 221   110.27  -5.404478  0.758406   122.53  11.168572  1.625612
# 222   109.44  -6.325430 -0.761698   120.57  12.640135  0.920733
# 223   110.28  -4.378739 -0.854086   119.47  14.292548  0.538585
# 224   111.23  -2.017266 -3.971337   118.83  13.974679  2.590003
# 225   115.83   6.227073  1.170408   115.83   8.903723 -1.814021
#
# [226 rows x 13 columns]

# %%
#东方财富-经济数据一览-中国-外商直接投资数据, 数据区间从 200801-202012

macro_china_fdi_df = ak.macro_china_fdi()
print(macro_china_fdi_df)
# Out:
#             月份          当月     当月-同比增长    当月-环比增长         累计  累计-同比增长
# 0    2023年07月份         NaN         NaN        NaN  111800000    -9.80
# 1    2023年05月份  10850000.0  -18.421053        NaN   84350000    -5.60
# 2    2023年04月份         NaN         NaN        NaN   73500000    -3.30
# 3    2023年02月份  20690000.0   -6.039964   8.780231   39710000     1.00
# 4    2023年01月份  19020000.0   20.075758  72.126697   19020000    10.00
# ..         ...         ...         ...        ...        ...      ...
# 180  2008年05月份   7760960.0   58.421856   2.079078   42777890    54.97
# 181  2008年04月份   7602890.0   70.214971 -18.121715   35016930    59.32
# 182  2008年03月份   9285600.0   50.171752  34.026347   27414040    61.26
# 183  2008年02月份   6928190.0   52.801205 -38.142541   18128440    75.19
# 184  2008年01月份  11200250.0  116.422424 -14.460445   11200250   109.78
#
# [185 rows x 6 columns]

# %%
#商务数据中心-国内贸易-社会融资规模增量统计, 数据区间从 201501-至今
macro_china_shrzgm_df = ak.macro_china_shrzgm()
print(macro_china_shrzgm_df)
# Out:
#          月份  社会融资规模增量  其中-人民币贷款  其中-委托贷款外币贷款  其中-委托贷款  其中-信托贷款  其中-未贴现银行承兑汇票  \
# 0    201501     20516     14708          212      832       52          1946
# 1    201502     13609     11437         -146     1299       38          -592
# 2    201503     12433      9920           -4     1111      -77          -910
# 3    201504     10582      8045         -265      344      -46           -74
# 4    201505     12397      8510           81      324     -195           961
# ..      ...       ...       ...          ...      ...      ...           ...
# 101  202306     42265     32413         -191      -56     -154          -691
# 102  202307      5364       364         -339        8      230         -1963
# 103  202308     31272     13412         -201       97     -221          1129
# 104  202309     41305     25369         -583      208      402          2397
# 105  202310     18452      4837          152     -429      393         -2536
#
#      其中-企业债券  其中-非金融企业境内股票融资
# 0       1868           526.0
# 1        716           542.0
# 2       1344           639.0
# 3       1616           597.0
# 4       1710           584.0
# ..       ...             ...
# 101     2249           700.0
# 102     1288           786.0
# 103     2781          1036.0
# 104      629           326.0
# 105     1144           321.0
#
# [106 rows x 9 columns]

# %%
#中国年度 CPI 数据, 数据区间从 19860201-至今

macro_china_cpi_yearly_df = ak.macro_china_cpi_yearly()
print(macro_china_cpi_yearly_df)
# Out:
#            date  value
# 0    1986-02-01    7.1
# 1    1986-03-01    7.1
# 2    1986-04-01    7.1
# 3    1986-05-01    7.1
# 4    1986-06-01    7.1
# ..          ...    ...
# 438  2023-07-10    0.0
# 439  2023-08-09   -0.3
# 440  2023-09-09    0.1
# 441  2023-10-13    0.0
# 442  2023-11-09   -0.2
#
# [443 rows x 2 columns]

# %%
#中国月度 CPI 数据, 数据区间从 19960201-至今

macro_china_cpi_monthly_df = ak.macro_china_cpi_monthly()
print(macro_china_cpi_monthly_df)
print(macro_china_cpi_monthly_df.name)
# Out:
# 1996-02-01    2.1
# 1996-03-01    2.3
# 1996-04-01    0.6
# 1996-05-01    0.7
# 1996-06-01   -0.5
#              ...
# 2023-07-10   -0.2
# 2023-08-09    0.2
# 2023-09-09    0.3
# 2023-10-13    0.2
# 2023-11-09   -0.1
# Name: cpi, Length: 322, dtype: float64
# cpi

# %%
macro_china_ppi_yearly_df = ak.macro_china_ppi_yearly()
print(macro_china_ppi_yearly_df)
print(macro_china_ppi_yearly_df.name)
# Out:
# 1995-08-01    13.5
# 1995-09-01    13.0
# 1995-10-01    12.9
# 1995-11-01    12.5
# 1995-12-01    11.1
#               ...
# 2023-07-10    -5.4
# 2023-08-09    -4.4
# 2023-09-09    -3.0
# 2023-10-13    -2.5
# 2023-11-09    -2.6
# Name: ppi, Length: 328, dtype: float64
# ppi

# %%
macro_china_exports_yoy_df = ak.macro_china_exports_yoy()
print(macro_china_exports_yoy_df)
print(macro_china_exports_yoy_df.name)
# Out:
# 1982-02-01     8.7
# 1982-03-01    23.2
# 1982-04-01    12.2
# 1982-05-01    -2.5
# 1982-06-01    41.5
#               ...
# 2023-07-13   -12.4
# 2023-08-08   -14.5
# 2023-09-07    -8.8
# 2023-10-13    -6.2
# 2023-11-07    -6.4
# Name: china_exports_yoy, Length: 488, dtype: float64
# china_exports_yoy

# %%
macro_china_imports_yoy_df = ak.macro_china_imports_yoy()
print(macro_china_imports_yoy_df)
print(macro_china_imports_yoy_df.name)
# Out:
# 1996-02-01    55.8
# 1996-03-01    14.2
# 1996-04-01     8.7
# 1996-05-01     6.4
# 1996-06-01     4.5
#               ...
# 2023-07-13    -6.8
# 2023-08-08   -12.4
# 2023-09-07    -7.3
# 2023-10-13    -6.2
# 2023-11-07     3.0
# Name: china_imports_yoy, Length: 327, dtype: float64
# china_imports_yoy

# %%
macro_china_trade_balance_df = ak.macro_china_trade_balance()
print(macro_china_trade_balance_df)
print(macro_china_trade_balance_df.name)
# Out:
# 1981-02-01     -2.2
# 1981-03-01     -4.9
# 1981-04-01     -7.4
# 1981-05-01     -4.8
# 1981-06-01     -5.4
#               ...
# 2023-07-13    706.2
# 2023-08-08    806.0
# 2023-09-07    683.6
# 2023-10-13    777.1
# 2023-11-07    565.3
# Name: china_trade_balance, Length: 510, dtype: float64
# china_trade_balance

# %%
macro_china_gyzjz_df = ak.macro_china_gyzjz()
print(macro_china_gyzjz_df)
# Out:
#             月份  同比增长  累计增长        发布时间
# 0    2008年02月份  15.4  15.4  2008-02-01
# 1    2008年03月份  17.8  16.4  2008-03-01
# 2    2008年04月份  15.7  16.3  2008-04-01
# 3    2008年05月份  16.0  16.3  2008-05-01
# 4    2008年06月份  16.0  16.3  2008-06-01
# ..         ...   ...   ...         ...
# 169  2023年06月份   4.4   3.8  2023-06-01
# 170  2023年07月份   3.7   3.8  2023-07-01
# 171  2023年08月份   4.5   3.9  2023-08-01
# 172  2023年09月份   4.5   4.0  2023-09-01
# 173  2023年10月份   4.6   4.1  2023-10-01
#
# [174 rows x 4 columns]

# %%
macro_china_industrial_production_yoy_df = ak.macro_china_industrial_production_yoy()
print(macro_china_industrial_production_yoy_df)
print(macro_china_industrial_production_yoy_df.name)
# Out:
# 1990-03-01    5.0
# 1990-04-01    0.8
# 1990-05-01    1.7
# 1990-06-01    3.3
# 1990-07-01    5.0
#              ...
# 2023-07-17    4.4
# 2023-08-15    3.7
# 2023-09-15    4.5
# 2023-10-18    4.5
# 2023-11-15    4.6
# Name: china_industrial_production_yoy, Length: 374, dtype: float64
# china_industrial_production_yoy

# %%
macro_china_pmi_yearly_df = ak.macro_china_pmi_yearly()
print(macro_china_pmi_yearly_df)
print(macro_china_pmi_yearly_df.name)
# Out:
# 2005-02-01    54.7
# 2005-03-01    54.5
# 2005-04-01    57.9
# 2005-05-01    56.7
# 2005-06-01    52.9
#               ...
# 2023-06-30    49.0
# 2023-07-31    49.3
# 2023-08-31    49.7
# 2023-09-30    50.2
# 2023-10-31    49.5
# Name: pmi, Length: 214, dtype: float64
# pmi

# %%
macro_china_cx_pmi_yearly_df = ak.macro_china_cx_pmi_yearly()
print(macro_china_cx_pmi_yearly_df)
print(macro_china_cx_pmi_yearly_df.name)
# Out:
# 2012-01-20    48.8
# 2012-02-22    49.6
# 2012-03-22    48.3
# 2012-04-23    49.1
# 2012-05-02    49.3
#               ...
# 2023-07-03    50.5
# 2023-08-01    49.2
# 2023-09-01    51.0
# 2023-10-01    50.6
# 2023-11-01    49.5
# Name: cx_pmi, Length: 174, dtype: float64
# cx_pmi

# %%
macro_china_cx_services_pmi_yearly_df = ak.macro_china_cx_services_pmi_yearly()
print(macro_china_cx_services_pmi_yearly_df)
print(macro_china_cx_services_pmi_yearly_df.name)
# Out:
# 2012-04-05    53.3
# 2012-05-04    54.1
# 2012-06-05    54.7
# 2012-07-04    52.3
# 2012-08-03    53.1
#               ...
# 2023-07-05    53.9
# 2023-08-03    54.1
# 2023-09-05    51.8
# 2023-10-01    50.2
# 2023-11-03    50.4
# Name: cx_services_pmi, Length: 131, dtype: float64
# cx_services_pmi

# %%
macro_china_non_man_pmi_df = ak.macro_china_non_man_pmi()
print(macro_china_non_man_pmi_df)
print(macro_china_non_man_pmi_df.name)
# Out:
# 2007-02-01    60.4
# 2007-03-01    60.6
# 2007-04-01    58.2
# 2007-05-01    60.4
# 2007-06-01    62.2
#               ...
# 2023-06-30    53.2
# 2023-07-31    51.5
# 2023-08-31    51.0
# 2023-09-30    51.7
# 2023-10-31    50.6
# Name: non_pmi, Length: 190, dtype: float64
# non_pmi

# %%
macro_china_new_house_price_df = ak.macro_china_new_house_price()
print(macro_china_new_house_price_df)
# Out:
#              日期  城市  新建商品住宅价格指数-同比  新建商品住宅价格指数-环比  新建商品住宅价格指数-定基  二手住宅价格指数-环比  \
# 0    2023-10-01  北京          102.1           99.6            NaN         99.8
# 1    2023-10-01  上海          104.4          100.2            NaN         97.7
# 2    2023-09-01  北京          102.9          100.4            NaN        101.1
# 3    2023-09-01  上海          104.4          100.5            NaN         98.1
# 4    2023-08-01  北京          102.8           99.8            NaN        100.8
# ..          ...  ..            ...            ...            ...          ...
# 303  2011-03-01  上海          102.0          100.2          102.3        100.5
# 304  2011-02-01  北京          108.4          100.5          103.5        102.9
# 305  2011-02-01  上海          102.8          101.1          102.1        102.0
# 306  2011-01-01  北京          109.1          101.0          103.0        102.6
# 307  2011-01-01  上海          101.8          101.1          101.0        101.7
#
#      二手住宅价格指数-同比  二手住宅价格指数-定基
# 0           98.9          NaN
# 1           99.2          NaN
# 2          100.7          NaN
# 3          100.6          NaN
# 4          100.4          NaN
# ..           ...          ...
# 303        100.4        101.4
# 304        100.4        101.5
# 305        100.4        101.0
# 306        100.3        101.2
# 307        100.5        100.6
#
# [308 rows x 8 columns]

# %%
macro_china_enterprise_boom_index_df = ak.macro_china_enterprise_boom_index()
print(macro_china_enterprise_boom_index_df)
# Out:
#            季度  企业景气指数-指数  企业景气指数-同比  企业景气指数-环比  企业家信心指数-指数  企业家信心指数-同比  \
# 0   2023年第3季度     108.60       8.60       2.70         NaN         NaN
# 1   2023年第2季度     105.90       5.90      -1.90         NaN         NaN
# 2   2023年第1季度     107.80       7.80       8.90         NaN         NaN
# 3   2022年第4季度      98.90      -1.10      -1.70         NaN         NaN
# 4   2022年第3季度     100.60       0.60      -1.20         NaN         NaN
# ..        ...        ...        ...        ...         ...         ...
# 70  2006年第1季度     131.50      31.50      -0.20      133.10       33.10
# 71  2005年第4季度     131.70      31.70      -0.30      125.40       25.40
# 72  2005年第3季度     132.00      32.00       0.29      127.60       27.60
# 73  2005年第2季度     131.71      31.71      -0.75      128.50       28.50
# 74  2005年第1季度     132.46      32.46      -2.27      135.85       35.85
#
#     企业家信心指数-环比
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 70        7.70
# 71       -2.20
# 72       -0.90
# 73       -7.35
# 74        5.04
#
# [75 rows x 7 columns]

# %%
macro_china_national_tax_receipts_df = ak.macro_china_national_tax_receipts()
print(macro_china_national_tax_receipts_df)
# Out:
#              季度     税收收入合计  较上年同期      季度环比
# 0   2023年第1-3季度  139105.00   11.9 -0.177462
# 1   2023年第1-2季度   99661.00   16.5 -0.072582
# 2     2023年第1季度   51707.00   -1.4  0.223863
# 3   2022年第1-4季度  166614.00   -3.5  0.088864
# 4   2022年第1-3季度  124365.00  -11.6  0.171811
# ..          ...        ...    ...       ...
# 68  2006年第1-2季度   18484.80   22.0  0.142837
# 69    2006年第1季度    8626.32   19.0       NaN
# 70  2005年第1-3季度   21855.35   15.9 -0.151249
# 71  2005年第1-2季度   15149.73   13.4  0.089860
# 72    2005年第1季度    7249.16   10.7       NaN
#
# [73 rows x 4 columns]
